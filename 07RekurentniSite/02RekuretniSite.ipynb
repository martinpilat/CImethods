# %% [markdown]
# # Rekurentní neuronové sítě
#
# Většina metod strojového učení předpokládá, že jednotlivé instance jsou nezávislé. Tento předpoklad je velmi často validní a pomáhá m odely zjednodušit, ale někdy se může stát, že potřebuje pracovat s daty, ve kterých nějaké další závislosti jsou, např. v ligvistice pracujeme s texty, které jsou uspořádané poslouplnosti slov a na jejich pořadí záleží, nebo můžeme pracovat s videem, kde jednotlivé obrázky za sebou také nejsou nezávislé. Někdy jde tyto závislosti ignorovat (např. pokud ve videu máme v každém obrázku něco najít), ale obecně to tak být nemusí a klíč ke správné klasifikaci může ležet právě v posloupnosti vstupů.
#
# Rekuretní neuronové sítě pracují explicitně s upořádáním dat. Kromě dopředných hran obsahují navíc i zpětné hrany, které předávají informaci do dalšího časového okamžiku (typicky do doby předložení dalšího vzoru).
#
# Trénování rekturentních sítí se moc neliší od trénování feed-forwards sítí, jen je potřeba síť tzv. rozbalit v čase, tj. nakopírovat ji přes několik časových kroků s tím, že rekurentní hrany vedou mezi těmito kopiemi a všechny váhy sjou sdílené. Rozvinutá síť neobsahuje žádné cykly a je možné ji trénovat pomocí back-propagation. Tato verze back-propagation se také nazývá back-propagation through time (BPTT).
#
# Problém při trénování rekuretních sítí způsobuje to, že se gradienty musí propagovat přes mnoho vrstev v rozvinuté síti (proto se také rekurentní sítě dají považovat za hluboké sítě). To vede k tomu, že gradienty buď konvergují k nule, nebo naopak "explodují". To, která varianta nastane závisí na konkrétních hodnotách gradientů, ale např. v síti s jedinou rekurentní hranou dojde ke konvergenci k nule, když je gradient menší než jedna a k explozi, když je větší než jedna. Tedy na jeden z problémů narazíme téměř vždy.
#
# ## Long-Short Term Memory (LSTM)
#
# LSTM sítě řeší problém mizijícího nebo explodujícího gradientu tím, že nahradí každý neuron novou jednotkou. V ní je rekurentní váha, která je vždy nastavena na jedna. Obrázek jedné jednotky (memory cell) z LSTM sítí je níže (převzato z [1]).
#
# ![memory cell](memory_cell.png)
#
# V každé buňce jsou kromě vstupu ještě tři brány -- vstupní, výstupní a zapomínací, ty mají za úkol pracovat s vnitřní pamětí buňky a ovlivňují, co se do ní uloží, případně co se z ní smaže. Zároveň ovlivňují i hodnotu výstupu. Každá z bran se chová jako jeden běžný neuron, tj. spočítá vážený součet vstupů a aplikuje na něj nejlineární funkci. Vnitřní stav buňky se chová jako neuron s dvěma vstupy a lineární aktivací, v zásadě tedy počítá vážený součet svojí předchozí aktivaci a svojí současné aktivace (váhy jsou dané vstupní a zapomínací branou). Výstup celé buňky je potom hodnota vnitřního stavu pronásobená hodnotou výstupní brány, případně se na něj ještě může aplikovat nějaké nelineární funkce.

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.datasets.data_utils import get_file
import numpy as np
import random
import sys

'''
    Example script to generate text from Nietzsche's writings.
    At least 20 epochs are required before the generated text
    starts sounding coherent.
    It is recommended to run this script on GPU, as recurrent
    networks are quite computationally intensive.
    If you try this script on new data, make sure your corpus
    has at least ~100k characters. ~1M is better.
'''

path = get_file('nietzsche.txt', origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt")
text = open(path).read().lower()
print('corpus length:', len(text))

chars = set(text)
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 20
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: 2 stacked LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(512, return_sequences=True, input_shape=(maxlen, len(chars))))
model.add(Dropout(0.2))
model.add(LSTM(512, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='rmsprop')


def sample(a, temperature=1.0):
    # helper function to sample an index from a probability array
    a = np.log(a) / temperature
    a = np.exp(a) / np.sum(np.exp(a))
    return np.argmax(np.random.multinomial(1, a, 1))

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y, batch_size=128, nb_epoch=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for iteration in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# corpus length: 600893
# total chars: 57
# nb sequences: 200291
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 2.8894
#
# ----- diversity: 0.2
# ----- Generating with seed: "imself
# because weari"
# imself
# because wearis the the the the the ses and ante the ane the the the the and the the the the the the the se the the the the the the the the the the the the the se the the the the the the and ante the the the se the the the the the the the the the an an in the the the the the the the the the the the the the the the the the the the the the ane the an the the se the the the the the the the the the the he the the t
#
# ----- diversity: 0.5
# ----- Generating with seed: "imself
# because weari"
# imself
# because wearig on ge the an the monl ole tas th ant the peathe toe the sos ant thor this te an the the an seth ins an innind in s ans oritin boslechecind ansthe th anging whe tho ther te shes an one in thene the hhe se lite tith ins-eoth an
# torhe the whad brethe hhins hor this the th ant the the e los wos hhe in ote this the rer she inle an on ane toe the the the peselin ile ho
# ber eos the the phe le the merhe
#
# ----- diversity: 1.0
# ----- Generating with seed: "imself
# because weari"
# imself
# because wearim!gag op oor e thelcet oenle re phorccwey cosunre ledd as,a rerateet anthigsit of mfieri
# nacte sutuee sode p ohal benbteligad,,y,,d:y themno o4atyer enad)uredciniggewer orentho-seasam havencigses vis astbenp ironoderi-reuof an c
# ankis, " vamo kleon to se
# senhk onlt indtaln. mhe, id alshes
# nlenceser henvy.!v, gqsto tanog wouter
# oesem:
# -to niuthe theigs if pimuejl to dy thin iw sh veas re baer manl
#
# ----- diversity: 1.2
# ----- Generating with seed: "imself
# because weari"
# imself
# because weari'yitoy " wherh uj
# atees tlcas orditle (hu)ltos thesidanresyli, in tealltas redr besern-cass inct houlhte goe teoced ius
# o thass
# ann.rhyyt-khe ae, toread-n(éy fonlamsd!![ phote bo e uphhe w is cres,er0 no tis
# saras; cfangitnr,
# elenk,are plsagtmt te tbaesmlp. apalc:er fiby te tho
# hy nos2bcheimesimonnd-ordachdid thes;sa(s phumibcindtek ypy finotiy
# m theellon ddiss enete sse ar]isily-. tersnciu-o!l a
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 200291/200291 [==============================] - 331s - loss: 2.3883
#
# ----- diversity: 0.2
# ----- Generating with seed: "to the thought he ex"
# to the thought he exting of tha pore for the and co the pores the mond and the the the sore the mond the core the pore the wore the panders of the and in the ale and the prich ald as the praciling of the ind the core for the salle the pares of the sore ale the sore the praned of the freing of the pales of the cand and the and the and the ale in the parer the sere of the whor the pores and and in the mole the mast of
#
# ----- diversity: 0.5
# ----- Generating with seed: "to the thought he ex"
# to the thought he expores of the ind in le pales the rethar the soll there as and co melcore to the the sherm-lher and the somres a domeuce siml, and of the porertis on the partoll gis the fore fore ald and whath chors sement ene as the arer nes the lened ald of the mesening and sighed the the lofer sor in the core the erer-sels a mamlang of preracige andere the asl is fere on the fulle, in deriss in a righand wherig
#
# ----- diversity: 1.0
# ----- Generating with seed: "to the thought he ex"
# to the thought he exhasm cousy ols agdinces ho turdeny and fhor is theme ruotucgorw
# he
#
# uvweu mere forgssy ot hancwi"niniher anol
# eqwiniturlics of. bound
# the drorte feret
# and drelmtyr ban -fu pmidps alosanisl sith lias, orest lo thy plelsk, -aaglisp, casthaln ale delen gidutesy the only xour of.m thine hopdaliesf, efae furcorad trabe ore a a therliagre rutaes dsoregvacerds-ess the sohe the exortiss tothers, hull to k
#
# ----- diversity: 1.2
# ----- Generating with seed: "to the thought he ex"
# to the thought he exade nlaleng ore fongiritho lsagim,,d wide
# as,
# alf of imilstthiobd cone palo. k6y
# lo2l coudpliy,ios
# the ë.lelpicys whe
# ptho-ly rand thas, stry bulte
# d anridcnbadtimads of anctcrownm, asde! a
# iost lob
# tavitre iot fus
# ipm pyemns;-d6 angumdann;, 3pacdrasils and pufcth-u. mor,
# ilsicaclncisunis,
# il sot whel ithor
# gti"te
# sondowaol. dreenthereme suscumeoneg, b pxeuso buchsud
# rastof of nlogcensch, geubt s
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 200291/200291 [==============================] - 331s - loss: 2.1761
#
# ----- diversity: 0.2
# ----- Generating with seed: "er, more extended, m"
# er, more extended, more the some and the rate the resting of the reation of the inderting of the some and whe has and the sore the sore the reation of the reation of the reathing the resting of the sore the some and the sore of the sore the seal and the rean the preat of the sould the sould the soul the sore the sould the sould and the some the rower the somen and in the wist of the rean and the nowers the sone the s
#
# ----- diversity: 0.5
# ----- Generating with seed: "er, more extended, m"
# er, more extended, mores to the deation of the sorctact of the sulle the prest and whe lent of in alling the mist of the demtan
# the conterss and the sond the chaens of and and in the ertorent of the porter in thit ofe man the ensares to mant and the andly--he mant the some one ane tho bel
# and the and in the sopals the praste tis the fore and the mesting and the wast of ont the would to indore hat whal the sondens for
#
# ----- diversity: 1.0
# ----- Generating with seed: "er, more extended, m"
# er, more extended, mom ty reatr, on the bivily walls reaty rend
# waesan vorst and the kmintur
# the sice ilrtine asor that itsurhan st?y corm!ly hey tareantar alb, dot bithonte
# netior?. in wholg thime"y beowaln tool 9uthe
# ot orgouth-"utiin: are adain hat re the
# mistiove hac eceirsticning in lyicg, un in a congicn whith"d
# woald
# delikuny, perrels ates bean-teumat of hamis, tuther as reor the nomed tuy bentirutial,, the fr
#
# ----- diversity: 1.2
# ----- Generating with seed: "er, more extended, m"
# er, more extended, mriyt"
# and_iztling and defwuns feon, the athrarnc,, of the syalkong bapcifsce acdunt agferse whe tous op uince of
# mery enwith gyean astaraonce
# on0icand elimicanly--mot eabsir;: agtive, alv in atevenes of thatich, joigrong rue
# guall
# uæ
# th.
# ozjowinall dee os the soruirulow ne laencemfat atteuserues
# of or oxg bint rathirut ofar)
# "ustt
# ttok. in a leisy?--1turhe bo calgarlod ale vullival. "? uontaven in
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 200291/200291 [==============================] - 331s - loss: 2.0216
#
# ----- diversity: 0.2
# ----- Generating with seed: "hree of these are th"
# hree of these are the sould the some the condertion of the sontion of the some the more the some the some the proming the porstion of the sould the serperses of the some the some the some the some the some the some the sould the some the some the selfing the sould and the prostion of the sance of the sinctare of the manters of the sould the some the somled the some the some the proment of the sould the more of the so
#
# ----- diversity: 0.5
# ----- Generating with seed: "hree of these are th"
# hree of these are the sesf the will is sould conse been sould condinity of the sollers of the statia is the list of the
# gromath in the stremations of the shille of the solly and the sinct in the sermore, in the precance of the calle-the constion of the apromations of the exprection of the conce protonigion of siminces of
# the more the scolly, then ars and manting and degured of
# the seopters of the tromis, who heor the
#
# ----- diversity: 1.0
# ----- Generating with seed: "hree of these are th"
# hree of these are tho great,
# o heweifility of lonce lower the one qonorech the espiencl which has lysibltent sonall,,, whith be,
# head toovinilals,
# whe speceimm and
# sturts
# and ifsde areng-to the its:e"ty very-windiss fles excoare
# to
# ubcherong lifher rolltar porsifucurces of
#
# u)ptrtice of ly perang that whe plonde
# stus
# all fumlatict, thar loigh welvayny the prialg erpernion, who ores welatule:
# ir notseds too his tuen
# m
#
# ----- diversity: 1.2
# ----- Generating with seed: "hree of these are th"
# hree of these are the
# tre=s now
# of ment rolkcrence on emon think in
# ellymtoine,
# illy; ore estorvam ouut wall
# the dychesved menting comlaxsman. to is hyoly. in this allomhen"--that seir ablaty thitpenty, ou
# geom unoveit, the oroly--ho mhacs
# imfived progodiet).
# funkempend, or pertemt ice to m fon
# wirkeo in
# ravain atollegis,"
# ho!, be
# welvan exjery, ussived as for grecerce, which alones in
# pulemwohibally) the grolubar re
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 200291/200291 [==============================] - 331s - loss: 1.8982
#
# ----- diversity: 0.2
# ----- Generating with seed: "chology
# is once more"
# chology
# is once more and in an and and and and and and all and deal and preasions of the some and man of the some and and the some of the sentions of the some and and and and and and and and and and his of the rear of the sence of the some and all the senters and all the sensions of the some and all the sence of the will to the some of the some of the some and and and indigions of the some of the sould to the some an
#
# ----- diversity: 0.5
# ----- Generating with seed: "chology
# is once more"
# chology
# is once more and all every and and his an ansifally there as an and encine can to the more praled and the spilition fireled in the some to be all as preasons and prilosophers and all agpee all the more and presions and will to his compling and his of his wimh and concerian there are instinct and and ever the
# sullitions and instinct, as in for the not
# disfore are simplagion and onding to kind and this find the
#
# ----- diversity: 1.0
# ----- Generating with seed: "chology
# is once more"
# chology
# is once more
# itsicol, weir horarity of a matherfile in
# suse fis
# perality al well somethings and orrepuliatations weer trong
# jlyz theunt gat acounding at
# our arure the sag, fics, for kuscibme of
# welustty serfattes in or granity" from
# so merigust and
# urird dot a fifmute takes ind casion himser and his enderse and
# germatusty prenamermations frequression..
# this mocer" outre,) and a commant] ay a lasn of pspicest
#
# ----- diversity: 1.2
# ----- Generating with seed: "chology
# is once more"
# chology
# is once more finuthech, sprigitfable ou? on?
#
# t   thut
# caucs fusciars,
# and rosits 6foeltions, armmacansevirias mar, ascemy and consignest thear preqeals=.e
# of sirces one
# qucliedisy aghinco evilisss oforirity--wlacer! of inston. while fuct. yeess soce, affee erthe, furloos gramanoud censif ince is almays thinksophere', and parse, sateæinaidmon and dufand zewsues must fiveloutly ensimade aro
# kelea vored" betal
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 200291/200291 [==============================] - 331s - loss: 1.7914
#
# ----- diversity: 0.2
# ----- Generating with seed: "nd them out! it is t"
# nd them out! it is the sentered the sentere the sempores of the will the sentere the sentere the sentere the senter in the sement of the sempless of the some the self of the sentered and the semert of the most and which the semple of the some of the some and the self the sentere the senter the semperience of the sentere the sention of the sentered to the self of the sentere the semparity of the sention of the sempost
#
# ----- diversity: 0.5
# ----- Generating with seed: "nd them out! it is t"
# nd them out! it is the same and he desine and all the pistulical mest of the something of the will to the sime of the
# commanable imstlict for the pristere of himself who can its
# life the will most which his self-conderour and is not the rastion of the most is recelfer in the instance and with all the dese of the restine of the sentent of his one some the
# present of the indicious for a mean of the great to be whole ev
#
# ----- diversity: 1.0
# ----- Generating with seed: "nd them out! it is t"
# nd them out! it is the some
# heweéiourly heventalled perphen in posbledity, with bild wo kal? and
# all, this bow it disture for which the tome realint good a sayte;, fir underst im these al or ond recale dome of somh.
# miscusionios, be
# mast aboly a prast,
# and misiols and patren of the guets and sach farmes of himself peisent is thus his regeded itself verite,. aise
# alroit disciance, how prisrasions of liktle, coured
# thi
#
# ----- diversity: 1.2
# ----- Generating with seed: "nd them out! it is t"
# nd them out! it is than to sels for the dosence priph. (
# maty, them freisless"
# and be,
# ant his "rukaf onweredual
# "ne that is a gond the
# semfan thoog, no logic, is to .,
# twethozast this cerse3n, in nangly this eively it the gerst facs=tingly byos, in 'aritiss himhelse wo loo dake. incassient to ho=se" the)m the "gruefase,
# the
# bist of the
# erapce aspealies, wh chouth intertring with the clomoch phishar oferuph at sage
# w
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 200291/200291 [==============================] - 331s - loss: 1.7016
#
# ----- diversity: 0.2
# ----- Generating with seed: " folly and chance wh"
#  folly and chance which is the some of the some of the sould of the some of the soul of the sention of the sentition of the sould to the sention of the sould the same the sention of the sould of the possible and the former the same of the some the something and the some to the sention of the something the some to the some of the some of the order of the some and the some of the into the world the such a some and the
#
# ----- diversity: 0.5
# ----- Generating with seed: " folly and chance wh"
#  folly and chance which the even the hard of the sain that the waster in the some and destoring and the greater and the most and suffer that is the souling the hempichter it is to be trunger the sentitions of the some and the something the same to sumpreation, the posso the lens to be a man in the world of the standing of the incertaint in the precourness and been seeven with the self to the suge of the sape of even
#
# ----- diversity: 1.0
# ----- Generating with seed: " folly and chance wh"
#  folly and chance which sor that
# thouke  this condiccably simply,e and houbdubly, curto and
# to frivold time and thir owk of poter of othertide depiscisity an yver treatents firmtade the disgon tase a be
# ones on this indnithtensed math instinct--truyhion couls the corn provally low the from the owred condations to
# be
# taker.
# a7ser--to sore tise,
# in itablie, cremanging to a be
# the chrigle
# chargenclss and as a forngions
#
# ----- diversity: 1.2
# ----- Generating with seed: " folly and chance wh"
#  folly and chance whis
# ghivts renution as regard, list esesmants, whinesspher that the popsonen ?org to lase
# ot to qorm, and
# d'ess of bre-"things.--thesluterics
# den-poncest whaces as tor entqresm, the good?
# it relulioud witho_ with somvele], in gadifarially bedy enjight understollthats upon imegassing
# pond tcour "flingmander of themsile in the mose derthan to longers=" tours, the beni
# deligious allusu-parrings, to ev
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.6305
#
# ----- diversity: 0.2
# ----- Generating with seed: "e hand is shy
#      t"
# e hand is shy
#      the experience of the conception of the conscience of the present of the standing of the inderstand the present of the present and stand of the most sense of the were and the present and strength of the present of the stronger of the present of the will and the concerts of the present of the problem of the most the most and and the problem of the stand of the conscience of the most even the stander
#
# ----- diversity: 0.5
# ----- Generating with seed: "e hand is shy
#      t"
# e hand is shy
#      the consequence of an ever whother many which the inality of the one sthenger with unout greates sime and superfaction of the light of the feeling, how to lave to be must also the light and the fance of the other fisting the child, not the lights of the shilt, in the world of the still deligion of the moman some and spirit and also a now the end the period of the most the inclens to the still that
#
# ----- diversity: 1.0
# ----- Generating with seed: "e hand is shy
#      t"
# e hand is shy
#      this
# peraling the cast, look, thene.
# mik nee
# stander at lide, why whele a mowe our free makes even the necseffically perhomanible, betates the omiginarces moracted and youthtry
# that is life objacted it
# wromes stull
# them, a maty still, he as means final to the findle to detine the modeencal
# ;oviems at whore in shatlefour and like jestion and whome any dedicmons
# and the indulity than the oldent moral
#
# ----- diversity: 1.2
# ----- Generating with seed: "e hand is shy
#      t"
# e hand is shy
#      tho bowh of them fenule to beloarst adave oul planefuble vole'nss, of all eppeas to think,
# of fan an the smoun
# spiring to impartacion
# as plesent ry natural old encertutys of kencwalf
# movech.
#
#
# 86
# =ponst makine wron: the fencimalizic hovevel.
# th7ouhally..
# gorded, to shord, and stand
# meghich,
# "ow) un very hand neaush; and by it, life whole wound greated opinion tage of
# excoppain doacting
# them, vist
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 200291/200291 [==============================] - 333s - loss: 1.5624
#
# ----- diversity: 0.2
# ----- Generating with seed: "one is apt to look u"
# one is apt to look upon the most sense of the something of the contring of the contemptance of the some of the experience of the soul of the soul of the most that the contring of the compersent of the postician and such a still the some of the actual of the present of the subjection of the same of the contrary of the present of the present of the subjection of the most many of the state of the something of the presen
#
# ----- diversity: 0.5
# ----- Generating with seed: "one is apt to look u"
# one is apt to look upon the most results of the contring of the crestion of the question of the comes of the promens of the point of the most the findamental conscience. actions of the world of the from science, but the become say that is suffering of his asticnate of the other of the spirit and enthisical emperiences as the sume point of self-string of the presing of the other will and also importing of the soul pon
#
# ----- diversity: 1.0
# ----- Generating with seed: "one is apt to look u"
# one is apt to look unone that the sulilations of venilation taud their of wanty, and everything sad wonls; for
# the
# mryacnoun couls devidence of impossible in fliend of definite, and habes ophosice men are enduch
# and men intentation, the
# gears in mestani, uretormine shat, aces inity gresttheth when a veart
# for these of yish[ence, and ave
# scire ecries of e itcormany, in one)end of which as all "meteryto axeast besich
#
# ----- diversity: 1.2
# ----- Generating with seed: "one is apt to look u"
# one is apt to look upon pnowwildew, and not, the understistil, clues" heswads friwere, it
# prays and phibosomelata_ willes, the eppuchioning grogps(ally to htice for himmental exexcs view.
# hæ
# awence--rearols masy ploe!nes; whene the vuresly,
# and ots anyews in dynichæinm nycisificate in ghem tatione xenize glem, and
# which hast, ane u can live
# out revilleves[es, when weed ondy as sprokounk very resonious of beind.
# -6no
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.5093
#
# ----- diversity: 0.2
# ----- Generating with seed: "sic, and such a shri"
# sic, and such a shride and individual with the sentiments of the subjection of the soul of the stronger of the soul of the sentiments of the sense of a stronger in the most something and the french of the same of the same of the same and the most decided and belief in the sentiments, and the sentiments of the soul of the spirit and the shepence of the suct and also in the soul and the most discountered and conditions
#
# ----- diversity: 0.5
# ----- Generating with seed: "sic, and such a shri"
# sic, and such a shrigt, in the end the space. the element of a contrance, as in the sense of general sabrity of a sentiments of generally and then he was the halited and self-befine the income sense of a contemplation to the most delight the life of the dear in the person of the endinar of the ineligion of a certain himself, that they ineternal decents and every and which men as in the same and even of the stronger i
#
# ----- diversity: 1.0
# ----- Generating with seed: "sic, and such a shri"
# sic, and such a shride is the browor hears not so facid and in:ividual and
# tanking. the most sessifice, and
# degornees, what has not lang we almost instance and the account of that shewenes? the foremoo restenting and mutther perspiling them.
# bond mosed the ofpenfal conceation, theneous earment,
# evication of hisself; one who has been differently.--veriskon.
# fuldome ghand to our exast
# veise not bicz we who condained "t
#
# ----- diversity: 1.2
# ----- Generating with seed: "sic, and such a shri"
# sic, and such a shriwilaininess, the soulf and there yrew whoje merr is gusk
# aste? in its world sthat ,ly
# nee
# surility for mush and reaghes
# theo,
# emanci,e it is allosg, a domain other what: svould frid=cesti while ne look; ceespent we hivinoy or censeat nog in the spoll, we
# our fucom, woill. how,
# wede a
# preath5ripations, whice mess dishamousemandran--of cas to the itself of the
# cru[tion dow "constitude")ial thenaberi
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.4587
#
# ----- diversity: 0.2
# ----- Generating with seed: "ldly, in hoary and s"
# ldly, in hoary and self-sense of the superfaction of the world of the individual of the individual with the sense of the still of the serves of the order of the subject of the world of the sense of the sense of the consciously of the individual of the sense of the subject of the sense of the sense of the present the present the consciously of the soul, the light in the consciousness of the individual of the conscienc
#
# ----- diversity: 0.5
# ----- Generating with seed: "ldly, in hoary and s"
# ldly, in hoary and so
# indigide to the ordance, or the present things and even the childron who says of it is not be sense to the sentiment of the the heart of the definest which he was seed to be man that the individual of the velicate of the spirit, the are of the stull of the world of the most ever with the most and befine the
# say to be ever one would have alloges the possible, and the seem-the of mank
# of mistipe,
#
# ----- diversity: 1.0
# ----- Generating with seed: "ldly, in hoary and s"
# ldly, in hoary and sometoricl' ests, shand, which bring litedical manneæs
# cain (the philosophices which yetire eopher more more for may les betine would rest agonginationing, whether the iligation of as the last be
# truinned.
#
# =42 itself to be moral fact acoursime
# the stand.
#
# 134. at mhanding morality is poopelise, that reaments of the bewith of datilist, who it leaven for
# a mmsitfires and valuation
# ofdem the
# singli i
#
# ----- diversity: 1.2
# ----- Generating with seed: "ldly, in hoary and s"
# ldly, in hoary and self demriching of=esisal stillise, puth di5fulice; zow that "getiply also for that have logr by still--adound the
# tance.- it is eepexhance lef uife is
# refinemed that of beloghs of luarr,
# inshind to on, rmpasted and avon; of
# menly, that of
# 2eligation, wishttomans far as a dspaking freature, the
# just pitures and capmen of this edi., here, he becomes it
# -0reany upon oblight] fi, wither a
# him. no mean
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.4130
#
# ----- diversity: 0.2
# ----- Generating with seed: "what?
# is that really"
# what?
# is that really in the contror of the soul and contrort of the same the most still to the contrint of the most sense of the controring of the present and present the present and contrarint the belief in the faith is the faith of the world of the longer of the soul and such a stronger in the contror of the contrort of the contrarict of the most extent the most deceived of the contror of the intellectual desires o
#
# ----- diversity: 0.5
# ----- Generating with seed: "what?
# is that really"
# what?
# is that really
# desires a certain conception of the present and seem of the incignoming of the uningention of the greater and the most reality of the consequences, and self-suctrificial the philosopher has been many does in the completion of the soul in the strong, and then in the present and destroud as the commonity of the present can dear in the completering of the soul according the intellectual french of st
#
# ----- diversity: 1.0
# ----- Generating with seed: "what?
# is that really"
# what?
# is that really or,
# germons. he cans desting
# man
# immote mady ty mire moves their harroties of the bettan inloved the same
# persand of
# a since, now with other
# whoweber the samveting anty, with a man in hame there
# are attained, concemoning and upon their
# condition of which
# tregiress the belief in all the interposious. such as wo lives nature as inco-something buring conintless reghas so the
# reverence and
# genone-sce
#
# ----- diversity: 1.2
# ----- Generating with seed: "what?
# is that really"
# what?
# is that really likes capely-alleces ;ings one who pencins of even to greature, 7exser
# thoting horality. ,neq intolemence on an
# i muli,are, is most culer all
# tohagetherac revection, crlest to. 'nroass, manibe
# to tomething--has igreater day rodacted or4
# rigenneps is.
# whened breathe soce-capres, we having as, which is even in the longers nequerty, we the truthluss rang
#
# bye spikit and
# with sadity man ones nature,
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.3703
#
# ----- diversity: 0.2
# ----- Generating with seed: "a comedy, and concea"
# a comedy, and conceals the same time in the present the same the same to the most sense of the soul and present the since of the same to the same to the same time and the same to the sentiment of the most spiritual constitution, the desires and in the same of the same of the contrary of the fact that is a consequently to the entire of the contrary of the same of the most saint of the most sance of the sentiment of th
#
# ----- diversity: 0.5
# ----- Generating with seed: "a comedy, and concea"
# a comedy, and conceals the person of the sentiment of the reconsition which the heart and unconscious to the spirit and a thing of the will of the constitution of the same of the conception, and many as it is the unfertand that is the world and subleard it is the same of the manner of a define the tere of the other hand the despecting the persent of the halffer possible something of the sacrifice that the distortion,
#
# ----- diversity: 1.0
# ----- Generating with seed: "a comedy, and concea"
# a comedy, and conceal nobvetow plaous and renifions hewitable and philosophers without any his proved of e7periences of the ocines according, and uttacter to the other pirture and
# period of
# the fal-anfored personal with it canitharis ?at beankarily, as to stupidiry
# that new forages. as it was the honour of the ertonarly when certament what light of diver for teséeor, and voltifily in poweous were generally has everyt
#
# ----- diversity: 1.2
# ----- Generating with seed: "a comedy, and concea"
# a comedy, and concealed in dis piver hal patole, derous! timese spuwish,
#
# mvaken, yee zrog--:we
# swendought it is unit to lightra
# gecmac be2ger thas abovest out of them. vistory of the relations of a jthestacic politions he not to sudfray free off-tor. mines ow, corsidt)--but of
# porgonaal agrancing. 1it of just, as puring--[laind pe only much be net iejul for oneæeled and
# impuris to
# tughes they where to oblyradivily t
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.3303
#
# ----- diversity: 0.2
# ----- Generating with seed: "s difficult and pain"
# s difficult and pain and the most extention of the sense of the sense of the sacrifice and the individual with our moral power, and all
# the most everything of the soul and the sense of the sacrifice of the same of the sense of the sense of the sense of the soul and the same things and an ending the sense of the same things and incention of the sense of the sate of the stronger in the soul who has been a made of the s
#
# ----- diversity: 0.5
# ----- Generating with seed: "s difficult and pain"
# s difficult and pain of the soul who has placed the understand of the sentiment of enoomence of the world
# indeed, it is to say the just in the former in the consequences of cantimity of the most demonstion of a certain of the world of the most sufficient that the impression of the noble of the lover of morals; the sense of the most even the consideration of others, whoce are sense of the soul which is the individual
#
# ----- diversity: 1.0
# ----- Generating with seed: "s difficult and pain"
# s difficult and painfulurace
# (one
# philosophy as exceed themselves dimike furlime;ast consequanvence. it is the utrega chooling
# oneses firmations and individual who have all tendent, of to, is so will find with a were plecepentiy kare, "these, therefire
# rang canving wish appearance of justercise into this notions! it has become him wyold at be repliced we seef exciencenculizan--and khols, the good greatferent scood of
#
# ----- diversity: 1.2
# ----- Generating with seed: "s difficult and pain"
# s difficult and pain!-
# exis its latter. thos tepelime.
# but our godq of thaiving
# eæucuding self sensiment attice is
# the way of the
# ounce?) commasds, for the manifest i.
# moethed, even
# the
# partle
# science of all respect is nghild they are
# people a(light and as promored and  oncowoofes that it is
# mokes. and if one is as" were wakniment
# 0new," this kind which it, i siptomhila
# but
# assit its highest
# an relisious gr'dound the
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 200291/200291 [==============================] - 331s - loss: 1.2896
#
# ----- diversity: 0.2
# ----- Generating with seed: "these, for
# instance,"
# these, for
# instance, and the consequences of the common that the same time and the same of the same time the commonal science of the common that the same time the form of the same that the same that the same thing of the soul, the things for the problems of the world of the problem of the complete of the same time the same that the same of the will to the spirit of the power, which is all the most discovery in the wo
#
# ----- diversity: 0.5
# ----- Generating with seed: "these, for
# instance,"
# these, for
# instance, and a sure-then are the soul in the great pleasure of the destruction of the same time is a depreciation of the individual.
#
#
#
#
#
#
# =the resulted to the other of the point of the very part of one soul, and a proverling men looked upon the world of the still the promost danger, the passion of the fail of the complete of the common to the unconsciousness of the problems of the virtues that which they
#
# ----- diversity: 1.0
# ----- Generating with seed: "these, for
# instance,"
# these, for
# instance, thing even
# the queticem5ness of our
# nelessical some matter, artwants when--belief in us, serfence, befarneby,, and
# "aspancing the whili, of it natereature to fher-brown with regander to done it, is to say in virtues: gravousn of place.---a; whith the pount leddiness time, and in the owpose with the good of the colwor] stspe
# truth;--very spayes itself; for everyly the owe of l'traite and through u
#
# ----- diversity: 1.2
# ----- Generating with seed: "these, for
# instance,"
# these, for
# instance, who kinks that, perhaps myself:ician,. and
# arrinctrusively conctinad to
# him beytiw;ly botw whoever thoughts, the best extent man, a pretwical, clear whoce the schopenos. have thenes?--they
# so erascerived when hand neqiess is
# according to best itselv, gifed in the poitt; of the
# subcett" that he reads be abtro feel an0tre: horpited, and latres for brow their philosophers, the anietain world,
# everyg
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.2514
#
# ----- diversity: 0.2
# ----- Generating with seed: "lls, or strive and t"
# lls, or strive and the same to the entire soul,
# which is the same of the order of philosophers and self-contrary, the manner of the same time and account of the complete process itself and the desire for the sense of the same to the desire for the properthes of the end the same of the same time and the sentiments of the entire sense of the same time and the desire for the sense of the soul, and the problem of the pro
#
# ----- diversity: 0.5
# ----- Generating with seed: "lls, or strive and t"
# lls, or strive and the feeling of a constraint, the distance of the most sintenest of himself, of the end in his sympathy, is no longer men of the same of mank possible to the
# extent of the will to the "artimete of existence in himself to be only one as the problem. desires the
# lapser stand in the morthed of the rest of the intellectual completeness of the will to properedute of a personal manner of such a mannon of
#
# ----- diversity: 1.0
# ----- Generating with seed: "lls, or strive and t"
# lls, or strive and their (one sight
# for all, the monimatisgs of a agarnsw-domboun which, whether the very refinements of
# appherimate truth us a love and constraint, and bcholder
# into the elseqtic narroprited, we may be mackad. and perhaps die
# domm whoma)--of conscience, less the
# namilaris--develtpinace itself preasure
# assicide worlds heart, the properstuly to the free, for ring means, pheservistim
# be moraly ofdoness
#
# ----- diversity: 1.2
# ----- Generating with seed: "lls, or strive and t"
# lls, or strive and torght muditable thar psychological, emotible mexopry-becoud of ig. failuti[-impplichianiny-thatching gract andteller of a thank of silt-- tring at the other ucknies:
# arvifted for ag:ions--and circumspacd in my tom' refent æow "touthfrees within its
# [intererable composedy, mumally obsyrictive
# gemald feas not of
# "mird?"  the ond hold hand, pire
# must no belief il has beent an a?timate placth, hace wh
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.2128
#
# ----- diversity: 0.2
# ----- Generating with seed: ". and we foremost, w"
# . and we foremost, we are strangely standpold of the profounded with his profound end the same of the soul and the problem of the strongest and more stronger and strained the strongest into the world of the possible for the sense of the contrary, the most sense of the power of the world with his conduct and self-controd of the person who has profound desire for present the possess of all the most suffering and streat
#
# ----- diversity: 0.5
# ----- Generating with seed: ". and we foremost, w"
# . and we foremost, with it and profoundly and caprible to a metaphysic and
# construction of the foolest resort of the sentiments of his profound even but be the freedom of the souls which has been hand defined and strained live and invistially will not be
# independent of the ancient language some one singly and origin of the profound. fullime the respect is clater and more difficult to one's own tince and profoundly de
#
# ----- diversity: 1.0
# ----- Generating with seed: ". and we foremost, w"
# . and we foremost, what it stell conception of things. in oher is to profe than to symbal tys, only as we have to me
# now stan onjy dows to made
# by a good feel profound
# unconditionom--i. it master we, the old trounterporral immediately
# cannot geting other who exists on unnecty'ism, in its creemetime,
# the every" individuals
# tok clie:
# and recongerlight in althing itpesceptip off equal and certainly) there then upon stol
#
# ----- diversity: 1.2
# ----- Generating with seed: ". and we foremost, w"
# . and we foremost, what achomech manifise, hic canner
# [poo-jlige?=--the 2old fell exist of matter, which exely nor have mideant. mankinable, and profoundly
# detry-vezed anqrest, superf intulture unlest wishes tead as one hee, has it
# ore:ly he geless in the worl' his spirit--[are ungertain )now to howly your wrong, the ill dest
#  "temme of obalmoration of power of plataters sense lan seeme destroided hind finds, loves!
#
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.1773
#
# ----- diversity: 0.2
# ----- Generating with seed: "l the obligations of"
# l the obligations of the world of the soul,
# when a man have a form of the same time and the desires of the soul, which is the real granted the belief in the contrary, the most still be mankind what he cannot all the most contraricting the belief in the world of the bound of the soul, the fact that the greater problems of the soul, and the most contraricting to the most difficult to the sight of the contlartution, the
#
# ----- diversity: 0.5
# ----- Generating with seed: "l the obligations of"
# l the obligations of
# ant who seeks to so! a conscious things and profection and disgained to the inegendence where experience to a here into the real good of the dear of mankind which have a sould they are not the contrary of the reason and consideration of the such a problems man who concerss he was believed. but the greater artists of the counterparation of the contrary, the falther the condition of the individual
#
# ----- diversity: 1.0
# ----- Generating with seed: "l the obligations of"
# l the obligations of german will as werjy the !me)ion was entermance it is
# owing that been the most inituren which cantd the without faith in, his conceals to him and
# has at maced "the spirit man, it is, only must for the most kningly--i see it has not denial only to grand their tyouble
# takin--in fact, for invopnite gous
# therefore honariation.
#
# - wa_ whoider at the best" if contsolation =ence, and deceover, that conn
#
# ----- diversity: 1.2
# ----- Generating with seed: "l the obligations of"
# l the obligations of byivelly..--.o
# , go out of
# kupand, in short?, where most costaple to the
# good of cordined doing the appropenerly to defed it be ne0ers,, itself desiret ove at tee
# which is  sivelled by sich
# wind and
# "afte" to so1theateners, commands)ly,
# inwerdefinc_) wheneves come so mudapets it had lif an intands aitures, that they a re-dee shooks wart become earoty
# and unconnuaredelit", the every "1pite" almos
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.1407
#
# ----- diversity: 0.2
# ----- Generating with seed: "n their compassion f"
# n their compassion from the philosopher has been a soul way the same thing of a conduct as it will be not to be the same thing of the same time and constant of the soul, the same time, the most delicate servilusm and contraricting for the proper may be made as it is the strongest science of the sense of the same time, the problem of the same find of a christian the present the same thing of the noble of the same thin
#
# ----- diversity: 0.5
# ----- Generating with seed: "n their compassion f"
# n their compassion from the philosopher, as the passion of the conscience of
# the light and more the termination of the explanations of a stronger in the point of life and contrarinting life of the belief in the responsible that the higher man, should be the point of the sense of the childre who are the deept nature of the earth of the most
# what deem he said the higher should not long teads as a changration of an ever
#
# ----- diversity: 1.0
# ----- Generating with seed: "n their compassion f"
# n their compassion from purious constraint or a still man, the mather us anything or radic beait-them engarily aol as bet theoreed whone which unegorsist, but
# as well then who fillers. the alrely to
# themselves in fact, it to wind a wermon
# means ardistress--as
# man we firt to day gow"--an enough for suffering and process. the castomment, an ominitate. cluss of europe of one's own social ver, instanct of
# such habdered w
#
# ----- diversity: 1.2
# ----- Generating with seed: "n their compassion f"
# n their compassion from ever the exotent are not youm whatout
#
# 2s4. a man of fave, and
# nobubleeds 9id, nowady, brates, science, for he, to be dormen of an enimitifut, it has been at
# are to mivellikmat.
# 03 the must steed mes from
# drain of inn'rence:--sater, they 1uct trutitieny and onet3icgst upon the alm:.
#
#
# 2h6  =nour not finfhire and
# 5etsity, it is once, and
# degoeted in his sourt, what ifuld closse, so, sancidet) i
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.1076
#
# ----- diversity: 0.2
# ----- Generating with seed: "n aspect endurable t"
# n aspect endurable to
# preference to the sentiment of all the most sense of the most since the contemplation of the problem of the most continually be a stronger protections of the origin of the problem of the most difficulty to delight the truth and the most difficulty to despined the most even of the extent that the most distunction of the individual who has been a longer the best and the most difficulty to delight
#
# ----- diversity: 0.5
# ----- Generating with seed: "n aspect endurable t"
# n aspect endurable to
# the complete as the superfountary man and thinks and some oness may be some taste all of theme to duniet that he who deep the same hind of the individual the entires of the great passion and a sentiments of
# all soul, not the truth as the noble of the reason, the absolute present that all the most
# difficulty to delight and finally conditions in the present that the master and the germanss of the
#
# ----- diversity: 1.0
# ----- Generating with seed: "n aspect endurable t"
# n aspect endurable to-pash maæ;er! is pyysology and
# the better woat as most estafyed
# of
# the similiar tretic for that whether to be orn erevers him even mises him to themselves (a vistocrate. with that the first of his tyou at the usance all kent to that with regard to the ultain of thit, who pare
# to
# dingelly is reason it will still one
# cannot be knowledges and that virtue conduct (something
# and took first uppess8nal
#
# ----- diversity: 1.2
# ----- Generating with seed: "n aspect endurable t"
# n aspect endurable to
# phellish in the forturate primordiality to what is
# labsely to that terrible of ge, spirituality.
# -.co. tdo"
# is what saves which like upon else i mean praser(ly
# o] gave al6o pi3it..
#
#
# ]52
#
# =senferbed to go place a constial, seem, is strange finalless igrovs and sut for
# deligious with whity
# absolutes rans and ainpered and
# anpyedononal examilyaty, natures the inities, wholey do not any rife todui4s
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 1.0727
#
# ----- diversity: 0.2
# ----- Generating with seed: "e is perhaps some sl"
# e is perhaps some slave, the more politic power, in the world of the scientific man is not a mast has always german things he say that he is a person where the same time the most delicate man in the most servent of the problems of the strongest in the sense of the extent of the most earner of the same part of the great problems of men, which is not the most servent of the soul and the world of men who has perhaps dec
#
# ----- diversity: 0.5
# ----- Generating with seed: "e is perhaps some sl"
# e is perhaps some slave, a sentiments of others,
# last, the most couragest in the restle the most definite and sensitive emotion of the astempt and desires and positions of the art of possibility, which is not considerations of the antithesis and more power, which is no still to heme and become explanations, which all longing to be love at all so is all the influence of a philosopher, has not been a long state and the
#
# ----- diversity: 1.0
# ----- Generating with seed: "e is perhaps some sl"
# e is perhaps some slave, in the longer. "he who expers a shold of say, "this which he which is coming than that shell continuanus on äusa1se] it reason-ity,
# itself ut is too hase
# on distrusti.ing and insight..
#
# 2q9. in jige to their
# almost very for havain
# to bjen hand--i  a dear not rith. should at the law with the accems has actuble of the disguise of it (as his susticion.=--it is so
# called is the vulity of the asce
#
# ----- diversity: 1.2
# ----- Generating with seed: "e is perhaps some sl"
# e is perhaps some sligh and medyw he guil, now "but when the fact that the question whether
# in the armoral spromps, inverted in cothom and endaining ambibues", to "ba shumple_," a s;uening of factich. poetn, us the revertespaity of all time in an
# ealogical other se=ses. focæ
# which "ufle physeonow: is merely the state of our emotions as the
# moments and sly"
# 3el.oculas. certain theor ?otw
# thus danggrist for the volunta
#
# --------------------------------------------------
# Iteration 22
# Epoch 1/1
# 200291/200291 [==============================] - 331s - loss: 1.0424
#
# ----- diversity: 0.2
# ----- Generating with seed: "nceited people.
#
#
# 13"
# nceited people.
#
#
# 13
#
# =precisely the postion of man, which is also the most delicate south, in a christian whome happiness of the end the most difficult to profound and account as it will also belong to the intellectual conscious of the most profound sentiments and poses, and are so much and before un their promise of the world of the intellectual formurasions, the problems of the problems of the intellectual conscio
#
# ----- diversity: 0.5
# ----- Generating with seed: "nceited people.
#
#
# 13"
# nceited people.
#
#
# 13
#
# =rovered in the great unconscious of the same period of the signtfo and
# in ancerbarness is not to be problem that it is also the problems of mankind, the problems of men, the charming of all their being the but ancient world an animal, there are not transit itself persustously, even the most singity of manifess something firmthers life in a religious and satisfictic to the mankind, what is no lo
#
# ----- diversity: 1.0
# ----- Generating with seed: "nceited people.
#
#
# 13"
# nceited people.
#
#
# 13
#
# =bevinfial of]er--one, the conception: "in the heart, oper? homevel,
# to which has difficulty of the distinction of ethers and fliengs of all saints, into the reason to all eyr
# "fauth," jut almaytement of "my.". this is in the common montry because is such as
# part, and ige--there are poss hame: at the state of the morality and heartinn--mexsulz, and of
# every widle, possible, and hoverever, the re
#
# ----- diversity: 1.2
# ----- Generating with seed: "nceited people.
#
#
# 13"
# nceited people.
#
#
# 13
#
# where is expreseded.;
# bnoughtund put on the older afupates unasturation_
# and flain und'rack o   :uther
# toen's that it was a" among the puttic tain to make regards pose is
# to be incontisung that not pentaile and exhelibul. and
# tielice just at the
# problem whine, at higher ments adakteradly
# to éive i have a man1-dang, muricress, soliture il--the with belief that puritoral tes. choicabe sible thing.
#
# --------------------------------------------------
# Iteration 23
# Epoch 1/1
# 200291/200291 [==============================] - 333s - loss: 1.0128
#
# ----- diversity: 0.2
# ----- Generating with seed: "holar in
# his superio"
# holar in
# his superiority and end the incontion of the soul, who will seem the common to the sense of the soul, when a moral freedom, or the sake of the problems of the same time the point of the saints of the most pain of the same time and the most difficult to the boundance of a benefit of the soul, and the soul as it is not the adeattered to the intellectual conscience, in the same time in the same manner of the sa
#
# ----- diversity: 0.5
# ----- Generating with seed: "holar in
# his superio"
# holar in
# his superiority and end
# in itself--it is the commonpent of an ansience of the some poist
# of the metaphysician with religion of the soul, who is the saint from such a
# character to the old morality of the solution of religion is the fact that the act of the same as the true of the intellectual scalces, inspire and so mankind of interpretation of the present they are those of the souls when the individual gods
#
# ----- diversity: 1.0
# ----- Generating with seed: "holar in
# his superio"
# holar in
# his superious.--it sould yet the claim, but assact suspicion is and the most matter of of the coulse of
# themselves to be regardade
# to the future of
# the most said grain of the "sustence)" is the capeliches with an
# in;5prenations of
# effect, tho knan, which, and
# their all in the foulds and exfaccation of ultimated life his strength as
# place, rusifal owing butted and wadled--a delipht all out of
# their juest goes
#
# ----- diversity: 1.2
# ----- Generating with seed: "holar in
# his superio"
# holar in
# his superiority, whoeter doctas, of upon assiéness
# -namely, the spirators with an
# audooo fear
# without this very distrust of cruezty, which rachs (with do! cally botk
# and-which flensme be schopenhauer: a
# sense of
# tieéty)) and his
# manifestation of generations)"; the useful'al mannes. wherever mese first s ever we fichar
# people causes pive
# sumponets and fasous. in thic materiation and insists in its
# hard, nighe
#
# --------------------------------------------------
# Iteration 24
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 0.9833
#
# ----- diversity: 0.2
# ----- Generating with seed: "demand in the souls "
# demand in the souls when the possibility of the world and the same to an end, a consequences
# of man, a condition of the world of the science of the sense of the science of the sense of the soul,
# which is the consequences of gratifuce the person whe have the powerful man is so far as the
# problem of the strong, to the sentiment of all the most estimation of the world of the science of the most entirent of all the most
#
# ----- diversity: 0.5
# ----- Generating with seed: "demand in the souls "
# demand in the souls in the most endincisms of the latter still in the possibility of the world of a morality, there are the responsibility of the sates: in the most delicate and adaits it is a consequence of the most equal decidity at the same to great, and feeling of the world
# after all, his personality as i change of its self content and
# occasionally, and when they are there
# are strangel science of a conscience of
#
# ----- diversity: 1.0
# ----- Generating with seed: "demand in the souls "
# demand in the souls the fact
# that presss in which
# the sas in such denilizate and rignon; in poult for dream of the fatilian musticism essualing arp. it will to unjexsicil skeation, should dring with the zumina is essible to pi4ces? it is a propert after-all men who has their
# self posyible, and has he to
# belofe--thege wrangs masters which ha perhapsed itself domstious freess,
# the will in a manner in succousces can sti
#
# ----- diversity: 1.2
# ----- Generating with seed: "demand in the souls "
# demand in the souls upon him. there after
#
# u29itory loves of danger by
# ruchuatord, will favely now!
#
#
#  non efference s; bething 3e is not the most developent stands be3ond who s when the green of plant cained "type"p" thrmath,"
# esceptions and diest'raded cas getihany was at ranks of direct.--i haugn the problem which an experience, himself seem, thelr-when ne scien in, is
# indeed, carrousd more fectimination. for t
#
# --------------------------------------------------
# Iteration 25
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 0.9550
#
# ----- diversity: 0.2
# ----- Generating with seed: "e," and with regard "
# e," and with regard to access in which the same time and also the most difficult to precention and extravagant free spirits the
# present the act of the presence of a religion of the soul,
# who has so called "intercerys in the sace of the contrarict in the most difficult to precention to the soul,
# who has no extravage the
# experiences, the unconscious of the soul,
# without all artist in some point, of the
# ever according t
#
# ----- diversity: 0.5
# ----- Generating with seed: "e," and with regard "
# e," and with regard to an ear, the most parries
# the world to the influence of this acts of a person when a man without having and actual nature will then the hand of soul,
# which man were a tented to man has assured and a something and if one charms as the race of the most science of the light for the
# commonarary artists of the self-contradictions and ears to uncertain and deceivion of the contrary, to curtume the sub
#
# ----- diversity: 1.0
# ----- Generating with seed: "e," and with regard "
# e," and with regard to the europe as hat is and it is difficult to precisila and entine follighton to what our nearerally hasf in the being of oftenes, arr ]ave, i8 not only be man.
#
# 22acter is a noble was the subjectual
# whocheres) "something plangous will
# with the principlow to the powerful,
# faush of friends--when the problems who has victurer, about youl. and  freedom, and wherever
# absold things a(deal.
# prace and c
#
# ----- diversity: 1.2
# ----- Generating with seed: "e," and with regard "
# e," and with regard to everywitook, ëust, the ruch thing
# of he free may be a masterlow of all untirstonality. there our
# matesially main.
#
# va. wanted and also at philosophuralss and
# cultures.
#
# "1m.
# in mhilousnys,) artame, as in the act
# and searment, pred
# indepted optrawes re lotz, and attained, a commanding- blith and not ore
# mostive to involuntary
# like the caces, the _rade, wished evougt, nither: as thou, thoy that
#
# --------------------------------------------------
# Iteration 26
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 0.9288
#
# ----- diversity: 0.2
# ----- Generating with seed: "ntercourse with one "
# ntercourse with one another far as of consciousness of all position and experiences, that the distance, and the desires of the very faith in his own possible." a man who has some partices of the perspention of the great called "canting to mankind will be taken out of the saints in a responsibility who think to the same pensulter--the genius of the same past of the same
# period the possibility of the every decide of th
#
# ----- diversity: 0.5
# ----- Generating with seed: "ntercourse with one "
# ntercourse with one another faith in the passion of the contemplation of an almost and their former times in such
# eight of the understand. his puilence of all solimure
# in the contemplation of an english man, what all, including subjection to the extent to instinct of the necessity for all and something complehension of the good of the place of men and
# resents for his self-sentiments, and supposing to the experiences,
#
# ----- diversity: 1.0
# ----- Generating with seed: "ntercourse with one "
# ntercourse with one could out of doment it is exciseed as
# a commanding and self-seniming, circu, and attemptible--that
# we not former. merewise medablly in the astamperous fact, the reason to
# domay alto. out of labection of piduars
# on the desarts of 9e)s, even in ordinary.
#
# 2237 of philosophy [rither to mankind
# in his degaining such dustrained bring it, its incestime not some poesions, the
# atsroused the cestame thereb
#
# ----- diversity: 1.2
# ----- Generating with seed: "ntercourse with one "
# ntercourse with one condoct and mucharientseds. in view to the old coulterate of certain many,
# all, out of different errmine of the even at
# philosophers twat is as it
# are to recuining subgect we all
# heirs, we all kto denpic frearmbir0n, oving--of
# remains, and also has, inder veribar.
#
#
# 11
#
# averoured his almost cayry it at anctyry general blen;--it is our emady hovent quile and the ié; connce of pity
# how many formally
#
# --------------------------------------------------
# Iteration 27
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 0.9066
#
# ----- diversity: 0.2
# ----- Generating with seed: "nsion to their congr"
# nsion to their congrary to the individuals and even of the individual and period of the scientific spirit," as the result of the most delicate ment of the present that it is not the formura of cause, and even the
# contrary of mankind--and still steething of the communicate belief in the most secunity, the general estimates of and soul, an incention and self-sentiment. but the world and the problem of morals and desire
#
# ----- diversity: 0.5
# ----- Generating with seed: "nsion to their congr"
# nsion to their congraint understanding and profoundly promound collecting his properame spirits;
# the were all of themselves for the most difficult to presural disgretacion his own powsiness of desirable and desires, and one
# sould such as in the resplitation of a condition of this nature. the french regards himself
# powers strivilus, and the comprehension of the highest uppored, in a pensona indeed, it is a
# considerati
#
# ----- diversity: 1.0
# ----- Generating with seed: "nsion to their congr"
# nsion to their congrain pecteccations which he yre
# highest processary his being neidser; he who are at pleasure and preceation"=d the ideal in hymotions. the weouth of plase? detarice and equality of
# religion
# in evication of which
# he is a faith in him the harmoness of the souls which has passiby to feel a general utility, which was been dif
# comprehens--the feering of
# furgasion, an atacti_ indignoun end to
# age many an
#
# ----- diversity: 1.2
# ----- Generating with seed: "nsion to their congr"
# nsion to their congradically stated, out of
# the ;act, and fectices; prared, when his pain alautable for re8ing while
# onese who are we about ith
# something wht comes que too
#  year äerst that oweriors and his part of tenerations, it is an individuals to deneration of smael'-
# who we kent first unlowed or distrust and you whosee at thems. this ;itser, and like foug tha
# kar-werfushing, s1ckeccal inridicalless unet actually
#
# --------------------------------------------------
# Iteration 28
# Epoch 1/1
# 200291/200291 [==============================] - 332s - loss: 0.8798
#
# ----- diversity: 0.2
# ----- Generating with seed: "least pleasing paths"
# least pleasing paths of nature. the most conscience of the consciousness of a sentiment of the moral feelings, of the antition
# of a christian who such a proper man will some subjlates and strength in itself and sure topthesism of the world and the community of the subject to the indest and self-desires, and as the are the problems of mankind and heart in such matters and strettle, and ancient lacking, the appear of
# t
#
# ----- diversity: 0.5
# ----- Generating with seed: "least pleasing paths"
# least pleasing paths in himself
# one wishes to say and also a present that all and
# has been something in the ancient lang
# with the individual can be
# armisted and unconsciously, the consciousness of a sympathy as world and streagel souls in the most
# still extent to a fear of the origin of the
# common to that the individual and profoundly be arrived at a man live and existence of self-absoruse place.
#
#
# 21
#
# =any venture f
#
# ----- diversity: 1.0
# ----- Generating with seed: "least pleasing paths"
# least pleasing paths
# being more to
# domination, the notion will
# artist what is
# once for the evil and
# many, this questional especially hear is rather thereby--respectable herduffienes and
# uaravisate te arbitrarily as out
# of the viral "upportranness in "stinlusines" of which
# one spould unto itself and unurefectionable besopularity
# and inspertation, apperious9 words and still soul, and who she
# decendency of the community
#
# ----- diversity: 1.2
# ----- Generating with seed: "least pleasing paths"
# least pleasing paths
# mime when certainly getracle, deals
# does even grateful itself 4ithept;
# 4uture, which is "my binale.'[--ad old s-untiming the medi2crem impression. the moral riscostition, the understanding his sit as
# thut are 0oughtsy for all that has
# been such our truthful jrden takt; alones that this "soul".=-ce"sitted!"
#
# 27(. egeriarmen.,--the
# symann andind the weakneism of blind andy is!eally finds and he sa
#
# --------------------------------------------------
# Iteration 29
# Epoch 1/1
#   2432/200291 [..............................] - ETA: 330s - loss: 0.7520
# Using gpu device 0: GRID K520
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-20c47838fe48> in <module>()
#      70     print('-' * 50)
#      71     print('Iteration', iteration)
# ---> 72     model.fit(X, y, batch_size=128, nb_epoch=1)
#      73
#      74     start_index = random.randint(0, len(text) - maxlen - 1)
#
# /usr/local/lib/python3.4/dist-packages/keras/models.py in fit(self, X, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, show_accuracy, class_weight, sample_weight)
#     487                          verbose=verbose, callbacks=callbacks,
#     488                          val_f=val_f, val_ins=val_ins,
# --> 489                          shuffle=shuffle, metrics=metrics)
#     490
#     491     def predict(self, X, batch_size=128, verbose=0):
#
# /usr/local/lib/python3.4/dist-packages/keras/models.py in _fit(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, metrics)
#     208                 batch_logs['size'] = len(batch_ids)
#     209                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 210                 outs = f(*ins_batch)
#     211                 if type(outs) != list:
#     212                     outs = [outs]
#
# /usr/local/lib/python3.4/dist-packages/Theano-0.7.0-py3.4.egg/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# /usr/local/lib/python3.4/dist-packages/Theano-0.7.0-py3.4.egg/theano/scan_module/scan_op.py in rval(p, i, o, n, allow_gc)
#     670         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     671                  allow_gc=allow_gc):
# --> 672             r = p(n, [x[0] for x in i], o)
#     673             for o in node.outputs:
#     674                 compute_map[o][0] = True
#
# /usr/local/lib/python3.4/dist-packages/Theano-0.7.0-py3.4.egg/theano/scan_module/scan_op.py in <lambda>(node, args, outs)
#     659                         args,
#     660                         outs,
# --> 661                         self, node)
#     662         except (ImportError, theano.gof.cmodule.MissingGXX):
#     663             p = self.execute
#
# KeyboardInterrupt:

# %% [markdown]
# ## Bi-directional Recurent Neural Networks (BRNN)
#
# V BRNN jsou dvě skryté vrstvy, obě napojené přímo na vstupy a výstupy. Neurony z jedné skryté vrstvy propagují informaci dopředu v čase (jako u běžné neuronové sítě). Neurony v druhé skryté vrstvě propagují informaci zpět v čase (tj. později předložené vzory mohou ovlivnit výstup u dříve předložených vzorů). Celá síť se zase po rozvinutí v čase dá trénovat pomocí BPTT.
#
# Právě propagace informace zpět v čase je na této síti zajímavá. Obecně nemáme k dispozici budoucí pozorování a nemůžeme je využít, ale existují situace (například v lingvistice při určování slovních druhů ve větách), kdy máme současné i budoucí informace najednou (v tomto případě za budoucí informaci považujeme další slova ve větě, větu typicky máme celou). V takových případech je vyžití informace z budoucích stavů prospěšné.
#
# ## Neural Turing Machines (NTM)
#
# NTM rozšiřují myšlenku ukládání stavu z LSTM a přidávají adresovatelnou paměť. Stejně jako Turingovy stroje mají čtecí a zapisovací hlavu. Zajímavé na nich je, že celá práce s hlavami a s pamětí je navržena tak, že ji lze zderivovat a síť učit pomocí back-propagation. Koho by to více zajímalo, nechť se podívá na článek [2].

# %% [markdown]
# ## Reference
#
# [1] Lipton, Zachary C. "A Critical Review of Recurrent Neural Networks for Sequence Learning." arXiv preprint arXiv:1506.00019 (2015).
#
# [2] Graves, Alex, Greg Wayne, and Ivo Danihelka. "Neural Turing Machines." arXiv preprint arXiv:1410.5401 (2014).
